# %%
# %pwd
# Out:
# 'C:\\Users\\ayame\\work\\tmp\\GHSponsors\\ipynb'

# %%
import pandas as pd

def read_csv(file: str):
    return pd.read_csv(file, header=0)

# %%
network = read_csv(r"../network.csv")
network
# Out:
#       sponsor       to spo_language to_language
# 0        dev0     dev1          Zig         C++
# 1        dev2     dev3         Rust        Rust
# 2        dev4     dev5        OCaml       OCaml
# 3        dev6     dev7   JavaScript         C++
# 4        dev8     dev9   TypeScript        Dart
# ...       ...      ...          ...         ...
# 2128  dev1474  dev1473   JavaScript      Python
# 2129  dev1079  dev1475   TypeScript  TypeScript
# 2130   dev893  dev1476            C           C
# 2131  dev1477   dev784       Kotlin      Kotlin
# 2132   dev784  dev1477       Kotlin      Kotlin
#
# [2133 rows x 4 columns]

# %%
to_language_count = network.groupby("to_language").count().sort_values("sponsor", ascending=False)
to_language_count
# Out:
#                   sponsor   to  spo_language
# to_language
# PHP                   456  456           455
# JavaScript            452  452           452
# Python                161  161           161
# TypeScript            124  124           123
# Go                    113  113           113
# C#                    111  111           111
# C++                    94   94            94
# Rust                   92   92            92
# Ruby                   91   91            91
# Java                   74   74            73
# C                      50   50            50
# Swift                  45   45            45
# Clojure                34   34            34
# Emacs Lisp             29   29            29
# Shell                  24   24            24
# HTML                   15   15            15
# PowerShell             14   14            14
# Kotlin                 13   13            13
# Vim script             13   13            13
# ...

# %%
to_language_count.plot.bar(fontsize=10, width=0.6, figsize=(12, 6), y="to", xlabel="lang", ylabel="sponsored count")
# Out:
# <AxesSubplot:xlabel='lang', ylabel='sponsored count'>
